# %% [markdown]
# # Scraping the Stock Data for LLM Fine Tuning

# %%
# !pip install yahoo_fin pyarrow requests_html lxml_html_clean beautifulsoup4 transformers torch
# Out:
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/fastparquet-2024.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/frozendict-2.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/yfinance-0.2.44.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/html5lib-1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/multitasking-0.0.11.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/cramjam-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/fastparquet-2024.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/frozendict-2.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/yfinance-0.2.44.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/html5lib-1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/multitasking-0.0.11.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/cramjam-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/peewee-3.17.6.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: yahoo_fin in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (0.8.9.1)
# Requirement already satisfied: pyarrow in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (17.0.0)
# Requirement already satisfied: requests_html in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: lxml_html_clean in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: beautifulsoup4 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: transformers in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (4.45.2)
# Requirement already satisfied: torch in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: feedparser in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from yahoo_fin) (6.0.11)
# Requirement already satisfied: requests in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from yahoo_fin) (2.32.3)
# Requirement already satisfied: pandas in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from yahoo_fin) (2.2.3)
# Requirement already satisfied: numpy>=1.16.6 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyarrow) (2.1.2)
# Requirement already satisfied: pyquery in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (2.0.1)
# Requirement already satisfied: fake-useragent in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (1.5.1)
# Requirement already satisfied: parse in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (1.20.2)
# Requirement already satisfied: bs4 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (0.0.2)
# Requirement already satisfied: w3lib in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (2.2.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: lxml in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from lxml_html_clean) (5.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: filelock in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (0.25.2)
# Requirement already satisfied: packaging>=20.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.77)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (2024.8.30)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (8.5.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (11.1.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.20)
# Requirement already satisfied: websockets<11.0,>=10.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: sgmllib3k in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pandas->yahoo_fin) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pandas->yahoo_fin) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pandas->yahoo_fin) (2024.2)
# Requirement already satisfied: cssselect>=1.2.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from pyquery->requests_html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests->yahoo_fin) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from requests->yahoo_fin) (3.10)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/fastparquet-2024.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/frozendict-2.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/yfinance-0.2.44.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/html5lib-1.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/multitasking-0.0.11.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/cramjam-2.8.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/crisco/source/repos/youtube-tutorials-pandasai/myEnv/lib/python3.12/site-packages/peewee-3.17.6.dist-info due to invalid metadata entry 'name'

# %% [markdown]
# ### Importing Models and Libraries

# %%
import requests
from bs4 import BeautifulSoup
from yahoo_fin import news
from transformers import pipeline
import warnings
import pandas as pd
import concurrent.futures
import unicodedata
import json
import re

#Initalize transformer pipelines
sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english", device=0)
summarizer = pipeline("summarization", device=0)
warnings.filterwarnings('ignore')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %% [markdown]
# ## Defining Helper Functions

# %%
def basic_cleanup(text):
    '''Perform basic cleanup on article text'''
    cleaned_text = unicodedata.normalize('NFKD', text).encode('ascii','ignore').decode('utf-8', 'ignore')
    cleaned_text = re.sub(r'[^a-zA-Z0-9.,;:!?\'\"()\s]', '', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text

# %%
def summarize_article(article_text):
    summary = summarizer(article_text[:2056], max_length=100, min_length=30, do_sample=False)
    return summary[0]['summary_text']

# %%
def add_sentiment(df:pd.DataFrame):
    setiments = df['article_text'].apply(lambda text: sentiment_pipeline(text[:2056])[0]['label'] if text != "N/A" else "UNKNOWN")
    df['sentiment'] = setiments
    return df

# %%
def get_article_text(url):
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            paragprahs = soup.find_all('p')
            article_text = ' '.join([p.get_text() for p in paragprahs])
            article_text = basic_cleanup(article_text)
            return article_text
        else:
            print(f"Failed to get article text from {url} got a response code of {response.status_code}")
            return "N/A"
    except Exception as e:
        print(f"Failed to get article text from {url}: {e}")
        return "N/A"

# %% [markdown]
# ## Fetching the Data from Yahoo Finance

# %%
stock_news = news.get_yf_rss("MSFT")
df = pd.DataFrame(stock_news)
df.head()
# Out:
#                                              summary  \
# 0  Boosted by big demand and an AI twist, GoDaddy...
# 1  The company has committed $1.6bn up to 2028 to...
# 2  Philippe Laffont's hedge fund, Coatue Manageme...
# 3  The American Forest Foundation will hold the U...
# 4  This stock can grant investors two benefits (g...
#
#                                       summary_detail  \
# 0  {'type': 'text/html', 'language': None, 'base'...
# 1  {'type': 'text/html', 'language': None, 'base'...
# 2  {'type': 'text/html', 'language': None, 'base'...
# 3  {'type': 'text/html', 'language': None, 'base'...
# 4  {'type': 'text/html', 'language': None, 'base'...
#
#                                      id  guidislink  \
# 0  8a0f7629-dd32-3689-ac8d-fb86f169ef59       False
# 1  f8d948f2-e881-3b60-a580-c929dcf18451       False
# 2  a53fc391-27dd-3270-acb4-ffc1e0c2f87f       False
# 3  2b9ac2ab-afb3-45ef-a183-1c08bdee8b62       False
# 4  0d91402b-c7be-3f9d-b9fc-61bda6ed770e       False
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://finance.yahoo.com/m/8a0f7629-dd32-3689...
# 1  https://www.power-technology.com/news/constell...
# 2  https://www.fool.com/investing/2024/10/17/bill...
# 3  https://finance.yahoo.com/news/first-us-auctio...
# 4  https://www.fool.com/investing/2024/10/17/here...
#
#                          published                       published_parsed  \
# 0  Thu, 17 Oct 2024 15:29:56 +0000  (2024, 10, 17, 15, 29, 56, 3, 291, 0)
# 1  Thu, 17 Oct 2024 14:59:53 +0000  (2024, 10, 17, 14, 59, 53, 3, 291, 0)
# 2  Thu, 17 Oct 2024 14:07:00 +0000    (2024, 10, 17, 14, 7, 0, 3, 291, 0)
# 3  Thu, 17 Oct 2024 13:54:03 +0000   (2024, 10, 17, 13, 54, 3, 3, 291, 0)
# 4  Thu, 17 Oct 2024 10:45:00 +0000   (2024, 10, 17, 10, 45, 0, 3, 291, 0)
#
#                                                title  \
# 0  This 'Big Daddy' Smashes All Mag 7 Stocks Exce...
# 1  Constellation orders transformer to revive Thr...
# 2  Billionaire Philippe Laffont Continues to Buy ...
# 3  First US auction of nature-based carbon credit...
# 4  Here's My Top Artificial Intelligence (AI) Sto...
#
#                                         title_detail
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...

# %%
df.columns
# Out:
# Index(['summary', 'summary_detail', 'id', 'guidislink', 'links', 'link',
#        'published', 'published_parsed', 'title', 'title_detail'],
#       dtype='object')

# %% [markdown]
# ## Preprocess the Data

# %%
def preprocess_data(df:pd.DataFrame) -> pd.DataFrame:
    df = df[['summary', 'link', 'published', 'title']]
    with concurrent.futures.ThreadPoolExecutor() as executor:
        article_texts = list(executor.map(get_article_text, df['link']))
    df['article_text'] = article_texts
    df = add_sentiment(df)
    return df

df_clean = preprocess_data(df)
df_clean.head()
# Out:
# Failed to get article text from https://finance.yahoo.com/video/election-cybersecurity-ai-healthcare-asking-225355609.html?.tsrc=rss got a response code of 400
# Failed to get article text from https://finance.yahoo.com/video/amazon-invests-500m-nuclear-microsoft-210914709.html?.tsrc=rss got a response code of 400
# Failed to get article text from https://finance.yahoo.com/video/mag-7-giants-continue-invest-221115292.html?.tsrc=rss got a response code of 400
# Failed to get article text from https://finance.yahoo.com/m/8a0f7629-dd32-3689-ac8d-fb86f169ef59/this-%27big-daddy%27-smashes-all.html?.tsrc=rss got a response code of 404
# Failed to get article text from https://finance.yahoo.com/m/a8d7ae12-1829-3dfd-aca0-243b0ffeb648/amazon-goes-nuclear%2C-sending.html?.tsrc=rss got a response code of 404
# Failed to get article text from https://finance.yahoo.com/news/mistral-ai-introduces-edge-ai-192143615.html?.tsrc=rss got a response code of 404
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#                                              summary  \
# 0  Boosted by big demand and an AI twist, GoDaddy...
# 1  The company has committed $1.6bn up to 2028 to...
# 2  Philippe Laffont's hedge fund, Coatue Manageme...
# 3  The American Forest Foundation will hold the U...
# 4  This stock can grant investors two benefits (g...
#
#                                                 link  \
# 0  https://finance.yahoo.com/m/8a0f7629-dd32-3689...
# 1  https://www.power-technology.com/news/constell...
# 2  https://www.fool.com/investing/2024/10/17/bill...
# 3  https://finance.yahoo.com/news/first-us-auctio...
# 4  https://www.fool.com/investing/2024/10/17/here...
#
#                          published  \
# 0  Thu, 17 Oct 2024 15:29:56 +0000
# 1  Thu, 17 Oct 2024 14:59:53 +0000
# 2  Thu, 17 Oct 2024 14:07:00 +0000
# 3  Thu, 17 Oct 2024 13:54:03 +0000
# 4  Thu, 17 Oct 2024 10:45:00 +0000
#
#                                                title  \
# 0  This 'Big Daddy' Smashes All Mag 7 Stocks Exce...
# 1  Constellation orders transformer to revive Thr...
# 2  Billionaire Philippe Laffont Continues to Buy ...
# 3  First US auction of nature-based carbon credit...
# 4  Here's My Top Artificial Intelligence (AI) Sto...
#
#                                         article_text sentiment
# 0                                                N/A   UNKNOWN
# 1  The company has committed 1.6bn up to 2028 to ...  NEGATIVE
# 2  Founded in 1993, The Motley Fool is a financia...  POSITIVE
# 3  The American Forest Foundation (AFF) recently ...  NEGATIVE
# 4  Founded in 1993, The Motley Fool is a financia...  NEGATIVE

# %% [markdown]
# ## Prepare the data for LLM Fine tuning

# %%
def prepare_finetuning_data(df: pd.DataFrame):
    training_data = []
    for _, row in df.iterrows():
        if row.get('sentiment') != "UNKNOWN":
            context = f"Title: {basic_cleanup(row['title'])}\nPublished: {row['published']}\nArticle: {row['article_text']}\nSentiment: {row['sentiment']}"
            question = "What is the sentiment of this article and why?"
            summary = summarize_article(row['article_text'])
            summary = basic_cleanup(summary)
            answer = f"The sentiment is {row['sentiment']} because: {summary}"
            training_data.append({"prompt" : f"{context}\nQuestion: {question}", "completion": answer})
    with open('ollama_training_data.jsonl', 'w') as f:
        json.dump(training_data, f, indent=4)

prepare_finetuning_data(df_clean)
